# %% [markdown]
# <a href="https://colab.research.google.com/github/aufagethsa/Pemerograman-Dasar/blob/main/Tugas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Latihan1

tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"

print(tegangan)
print(arus)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
#Latihan2

komponen = "Kapasitor"
tegangan = 18
muatan_listrik = 0.0018
aktif = True

print(komponen, type (komponen))
print(tegangan, type (tegangan))
print(muatan_listrik, type (muatan_listrik))
print(aktif, type (aktif))
# Out:
# Kapasitor <class 'str'>
# 18 <class 'int'>
# 0.0018 <class 'float'>
# True <class 'bool'>

# %%
#Latihan3

nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroprasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroprasi, type(sedang_beroprasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
#Latihan4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) pembacaan pertama  dan terakhir
print("pembacaan_pertama", tegangan_harian [0])
print("pembacaan_terakhir", tegangan_harian [-1])

# (b) tambahkan satu pembacaan terbaru
tegangan_harian.append(222.0)
print("pembacaan_terbaru", tegangan_harian)

#(c) jumlah total
print(len(tegangan_harian))
# Out:
# pembacaan_pertama 217.5
# pembacaan_terakhir 216.9
# pembacaan_terbaru [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# 7

# %%
#Latihan5

spesifikasi = {"nama"  : "Motor Listrik",
               "kapasitas_kW" : 3.7,
               "tegangan_V" : 380,
               "rpm" : 1500,
               "frekuensi_Hz" : 60,
               "indeks_proteksi" : "IP55",
               "status_operasi" : True
}
print("Nilai RPM awal:", spesifikasi["rpm"])
spesifikasi["rpm"] = 1500
print("Dictionary setelah diubah:")
print(spesifikasi)
# Out:
# Nilai RPM awal: 1500
# Dictionary setelah diubah:
# {'nama': 'Motor Listrik', 'kapasitas_kW': 3.7, 'tegangan_V': 380, 'rpm': 1500, 'frekuensi_Hz': 60, 'indeks_proteksi': 'IP55', 'status_operasi': True}

# %%
#Latihan6

pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]
print("nama unit kedua:", pembangkit[1]["nama"])

pembangkit[2]["status"] = "operasi"
pembangkit.append({
    "nama": "Unit-4",
    "kapasitas_MW": 180,
    "status": "operasi"
})
print(pembangkit)
# Out:
# nama unit kedua: Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}, {'nama': 'Unit-4', 'kapasitas_MW': 180, 'status': 'operasi'}]
