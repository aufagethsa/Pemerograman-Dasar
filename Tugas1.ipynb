# %% [markdown]
# <a href="https://colab.research.google.com/github/aufagethsa/Pemerograman-Dasar/blob/main/Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Aufa"
umur = 19
jurusan = "RPE"
semester = 3
mata_kuliah = "Pemrograman Dasar"
alamat = "Bumi Sakinah, Marwah 3"
hobi = "Membaca"
warna_favorit = "Pink"
makanan_favorit = "Ketoprak"
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (mata_kuliah)
print (alamat)
print (hobi)
print (warna_favorit)
print (makanan_favorit)
print (status_lulus)
# Out:
# Aufa
# 19
# RPE
# 3
# Pemrograman Dasar
# Bumi Sakinah, Marwah 3
# Membaca
# Pink
# Ketoprak
# False
